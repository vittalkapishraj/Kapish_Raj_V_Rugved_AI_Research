# %%
# %history -l 100
# Out:
# print(df.loc["John"])
# df = pd.read_csv("AB_NYC_2019.csv.zip", index_col = "host_name")
# print(df.head())
# print(df.loc["John"])
# #You can also use df.loc[index,[column_attribute1,column_attribute2]] to access only specific attribute of that row.
# print(df.loc["John",["host_id","id"]])
# print(df.iloc[0:4,["host_name","price","neighbourhood_group"]])
# print(df.iloc[0:4,3:9:5])
# print(df.loc["John",["price"]].sum())
# print(The amount earned by John is {df.loc["John",["price"]].sum()} dollars.)
# print(f"The amount earned by John is {df.loc["John",["price"]].sum()} dollars.")
# print(f"The amount earned by John is {df(df.loc["John",["price"]].sum())} dollars.")
# print(f"The amount earned by John is {df.loc["John",["price"]].sum()} dollars.")
# k=df.loc["John",["price"]]
# print(f"The amount earned by John is {k["price"].sum()} dollars.")
# x=df.groupby("host_name")
# print(x.sum("price"))
# x=df.groupby("host_name")
# print(x["price"].sum())
# x=df.groupby("host_name")
# ...
