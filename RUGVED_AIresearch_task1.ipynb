# %%
print("Hello Rugved Systems.\nThis is AI Research domain.")
# Out:
# Hello Rugved Systems.
# This is AI Research domain.

# %%
#TASK-1 Q1
def triple_and(x,y,z):
    if x == True and y == True and z == True :
     return True
    else:
     return False

# %%
triple_and(1,1,1)
# Out:
# True

# %%
triple_and(1,2,0)
# Out:
# False

# %%
#TASK-1 Q2
word = input("Enter any word to sort it in alphabetical order and geting length of it:").upper()
print("".join(sorted(word)))
print(len(word))
# Out:
# Enter any word to sort it in alphabetical order and geting length of it: kapish
# AHIKPS
# 6

# %%
#TASK-2 Q3
try:
    hill_number = int(input("ENTER ANY NUMBER TO CHECK WHETHER IT IS A HILL NUMBER OR NOT:"))
    k = str(hill_number)
except ValueError:
    print("Only positive integers should be written.")
# Out:
# ENTER ANY NUMBER TO CHECK WHETHER IT IS A HILL NUMBER OR NOT: 123
# 3
